# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df = df.drop('id', axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Age                      630000 non-null  int64
#  1   Sex                      630000 non-null  int64
#  2   Chest pain type          630000 non-null  int64
#  3   BP                       630000 non-null  int64
#  4   Cholesterol              630000 non-null  int64
#  5   FBS over 120             630000 non-null  int64
#  6   EKG results              630000 non-null  int64
#  7   Max HR                   630000 non-null  int64
#  8   Exercise angina          630000 non-null  int64
#  9   ST depression            630000 non-null  float64
#  10  Slope of ST              630000 non-null  int64
#  11  Number of vessels fluro  630000 non-null  int64
#  12  Thallium                 630000 non-null  int64
#  13  Heart Disease            630000 non-null  object
# ...

# %%
numericas = df.select_dtypes(include = 'number').columns.tolist()
numericas
# Out:
# ['Age',
#  'Sex',
#  'Chest pain type',
#  'BP',
#  'Cholesterol',
#  'FBS over 120',
#  'EKG results',
#  'Max HR',
#  'Exercise angina',
#  'ST depression',
#  'Slope of ST',
#  'Number of vessels fluro',
#  'Thallium']

# %%
df.describe()
# Out:
#                  Age            Sex  Chest pain type             BP  \
# count  630000.000000  630000.000000    630000.000000  630000.000000
# mean       54.136706       0.714735         3.312752     130.497433
# std         8.256301       0.451541         0.851615      14.975802
# min        29.000000       0.000000         1.000000      94.000000
# 25%        48.000000       0.000000         3.000000     120.000000
# 50%        54.000000       1.000000         4.000000     130.000000
# 75%        60.000000       1.000000         4.000000     140.000000
# max        77.000000       1.000000         4.000000     200.000000
#
#          Cholesterol   FBS over 120    EKG results         Max HR  \
# count  630000.000000  630000.000000  630000.000000  630000.000000
# mean      245.011814       0.079987       0.981660     152.816763
# std        33.681581       0.271274       0.998783      19.112927
# min       126.000000       0.000000       0.000000      71.000000
# ...

# %%
def generate_analisys(df, numericas, alvo):
    """Recebe um data frame, e as colunas numéricas do mesmo. Define um alvo, e, então, retorna os lineplots
    das variáveis numéricas vs as variáveis numéricas."""
    
    for coluna in numericas:
        sns.lineplot(data=df, x=coluna, y=alvo)
        plt.xticks(rotation=45)
        plt.show()
        print(coluna)

# %%
generate_analisys(df, numericas, 'Heart Disease')
# Out:
# Age
# Sex
# Chest pain type
# BP
# Cholesterol
# FBS over 120
# EKG results
# Max HR
# Exercise angina
# ST depression
# Slope of ST
# Number of vessels fluro
# Thallium

# %%
def var_overview(df, numericas):
    for coluna in numericas:
        sns.boxplot(data=df, x=coluna)
        plt.show()

# %%
var_overview(df, numericas)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Age                      630000 non-null  int64
#  1   Sex                      630000 non-null  int64
#  2   Chest pain type          630000 non-null  int64
#  3   BP                       630000 non-null  int64
#  4   Cholesterol              630000 non-null  int64
#  5   FBS over 120             630000 non-null  int64
#  6   EKG results              630000 non-null  int64
#  7   Max HR                   630000 non-null  int64
#  8   Exercise angina          630000 non-null  int64
#  9   ST depression            630000 non-null  float64
#  10  Slope of ST              630000 non-null  int64
#  11  Number of vessels fluro  630000 non-null  int64
#  12  Thallium                 630000 non-null  int64
#  13  Heart Disease            630000 non-null  object
# ...

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   58    1                4  152          239             0            0
# 1   52    1                1  125          325             0            2
# 2   56    0                2  160          188             0            2
# 3   44    0                3  134          229             0            2
# 4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        2         7      Presence
# 1                        0         3       Absence
# ...

# %%
df['Sex'] = list(map(lambda x: 'M' if x==1 else 'F', df['Sex']))
#Transforming into category, thus 0 and 1 doesn't have distance interpretation on sex

df['Chest pain type'] = list(map(lambda x: 'Light' if x==1 else 'Common' if x==2 else 'Hard' if x==3 else 'Dangerous', df['Chest pain type']))
#Transforming into category, same reason

df['FBS over 120'] = list(map(lambda x: 'Y' if x==1 else 'N', df['FBS over 120']))
#Transforming into category, same reason

df['Exercise angina'] = list(map(lambda x: 'Y' if x==1 else 'N', df['Exercise angina']))
# Transforming into category, same reason

df['Slope of ST'] = list(map(lambda x: 'Upsloping' if x==1 else 'Flat' if x==2 else 'Downsloping', df['Slope of ST']))
# Transforming into category, same reason

df['EKG results'] = list(map(lambda x: 'N' if x in [0,1] else 'P', df['EKG results']))
# Merging 0 and 1 to 'N' thus 0 and 1 have the same relation with Heart Disease and, transforming into category
# thus, here also, there's no distance relation between 0, 1 and 2

df.head()
# Out:
#    Age Sex Chest pain type   BP  Cholesterol FBS over 120 EKG results  Max HR  \
# 0   58   M       Dangerous  152          239            N           N     158
# 1   52   M           Light  125          325            N           P     171
# 2   56   F          Common  160          188            N           P     151
# 3   44   F            Hard  134          229            N           P     150
# 4   58   M       Dangerous  140          234            N           P     125
#
#   Exercise angina  ST depression Slope of ST  Number of vessels fluro  \
# 0               Y            3.6        Flat                        2
# 1               N            0.0   Upsloping                        0
# 2               N            0.0   Upsloping                        0
# 3               N            1.0        Flat                        0
# 4               Y            3.8        Flat                        3
#
#    Thallium Heart Disease
# 0         7      Presence
# ...

# %%
df_att = df.copy()

# %%
df['Chest pain type'].value_counts()
# Out:
# Chest pain type
# Dangerous    329179
# Hard         197278
# Common        74941
# Light         28602
# Name: count, dtype: int64

# %%
df['Heart Disease'].value_counts()
# Out:
# Heart Disease
# Absence     347546
# Presence    282454
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Chest pain type', hue='Heart Disease')
# Out:
# <Axes: xlabel='Chest pain type', ylabel='count'>

# %%
df_att.head()
# Out:
#    Age Sex Chest pain type   BP  Cholesterol FBS over 120 EKG results  Max HR  \
# 0   58   M       Dangerous  152          239            N           N     158
# 1   52   M           Light  125          325            N           P     171
# 2   56   F          Common  160          188            N           P     151
# 3   44   F            Hard  134          229            N           P     150
# 4   58   M       Dangerous  140          234            N           P     125
#
#   Exercise angina  ST depression Slope of ST  Number of vessels fluro  \
# 0               Y            3.6        Flat                        2
# 1               N            0.0   Upsloping                        0
# 2               N            0.0   Upsloping                        0
# 3               N            1.0        Flat                        0
# 4               Y            3.8        Flat                        3
#
#    Thallium Heart Disease
# 0         7      Presence
# ...

# %%
df_att.to_csv('df_att.csv')

# %%
df['Slope of ST'].value_counts()
# Out:
# Slope of ST
# Upsloping      358293
# Flat           256215
# Downsloping     15492
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Slope of ST', hue='Heart Disease')
plt.show()

# %%
df['EKG results'].value_counts()
# Out:
# EKG results
# N    321438
# P    308562
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Age Sex Chest pain type   BP  Cholesterol FBS over 120 EKG results  Max HR  \
# 0   58   M       Dangerous  152          239            N           N     158
# 1   52   M           Light  125          325            N           P     171
# 2   56   F          Common  160          188            N           P     151
# 3   44   F            Hard  134          229            N           P     150
# 4   58   M       Dangerous  140          234            N           P     125
#
#   Exercise angina  ST depression Slope of ST  Number of vessels fluro  \
# 0               Y            3.6        Flat                        2
# 1               N            0.0   Upsloping                        0
# 2               N            0.0   Upsloping                        0
# 3               N            1.0        Flat                        0
# 4               Y            3.8        Flat                        3
#
#    Thallium Heart Disease
# 0         7      Presence
# ...

# %%
sns.histplot(data=df, x='EKG results', hue='Heart Disease', multiple='fill')
plt.show()

# %%
# Now, we shall verify if there are outliars in on the vars of our df.
# Out:
# EKG results
# 0    320116
# 2    308562
# 1      1322
# Name: count, dtype: int64

# %%
categoricas = list(df_att.select_dtypes(include='object').columns)

# %%
categoricas
# Out:
# ['Sex',
#  'Chest pain type',
#  'FBS over 120',
#  'EKG results',
#  'Exercise angina',
#  'Slope of ST',
#  'Heart Disease']

# %%
df_att[categoricas] = df_att[categoricas].astype('category')
df_att.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Age                      630000 non-null  int64
#  1   Sex                      630000 non-null  category
#  2   Chest pain type          630000 non-null  category
#  3   BP                       630000 non-null  int64
#  4   Cholesterol              630000 non-null  int64
#  5   FBS over 120             630000 non-null  category
#  6   EKG results              630000 non-null  category
#  7   Max HR                   630000 non-null  int64
#  8   Exercise angina          630000 non-null  category
#  9   ST depression            630000 non-null  float64
#  10  Slope of ST              630000 non-null  category
#  11  Number of vessels fluro  630000 non-null  int64
#  12  Thallium                 630000 non-null  int64
# ...

# %%
# Now, we shall verify if there are outliars in our numeric columns, and verify what to do with them...

numeric = list(df_att.select_dtypes(include='number'))
numeric
# Out:
# ['Age',
#  'BP',
#  'Cholesterol',
#  'Max HR',
#  'ST depression',
#  'Number of vessels fluro',
#  'Thallium']

# %%
def numeric_ol_check(df, numeric_vars):
    for col in numeric_vars:
        sns.boxplot(data=df, y=col)
        plt.show()

# %%
numeric_ol_check(df=df_att, numeric_vars = numeric)

# %%
df_att.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Age                      630000 non-null  int64
#  1   Sex                      630000 non-null  category
#  2   Chest pain type          630000 non-null  category
#  3   BP                       630000 non-null  int64
#  4   Cholesterol              630000 non-null  int64
#  5   FBS over 120             630000 non-null  category
#  6   EKG results              630000 non-null  category
#  7   Max HR                   630000 non-null  int64
#  8   Exercise angina          630000 non-null  category
#  9   ST depression            630000 non-null  float64
#  10  Slope of ST              630000 non-null  category
#  11  Number of vessels fluro  630000 non-null  int64
#  12  Thallium                 630000 non-null  int64
# ...

# %%
df_att.describe()
# Out:
#                  Age             BP    Cholesterol         Max HR  \
# count  630000.000000  630000.000000  630000.000000  630000.000000
# mean       54.136706     130.497433     245.011814     152.816763
# std         8.256301      14.975802      33.681581      19.112927
# min        29.000000      94.000000     126.000000      71.000000
# 25%        48.000000     120.000000     223.000000     142.000000
# 50%        54.000000     130.000000     243.000000     157.000000
# 75%        60.000000     140.000000     269.000000     166.000000
# max        77.000000     200.000000     564.000000     202.000000
#
#        ST depression  Number of vessels fluro       Thallium
# count  630000.000000            630000.000000  630000.000000
# mean        0.716028                 0.451040       4.618873
# std         0.948472                 0.798549       1.950007
# min         0.000000                 0.000000       3.000000
# 25%         0.000000                 0.000000       3.000000
# ...

# %%
# As we verify the distribution of our vars, we can see some rare values, though, they are not explicit outliars.
# but some rare values in our exams results, or some rare appearances in our physical descriptions from the
# subjects, as age. They may abe important for our ML model, so we don't need to "fix" it now.
# We may reconsider it later though...

# We shall now verify if there are rare occurances in our categoric features that may be non significent, and
# though, may be merged with other ones...

categorical =  list(df_att.select_dtypes(exclude='number').columns)
categorical
# Out:
# ['Sex',
#  'Chest pain type',
#  'FBS over 120',
#  'EKG results',
#  'Exercise angina',
#  'Slope of ST',
#  'Heart Disease']

# %%
for col in categorical:
    print(f'A distribuição de {col} é:')
    display(df_att[col].value_counts())
# Out:
# A distribuição de Sex é:
# Sex
# M    450283
# F    179717
# Name: count, dtype: int64
# A distribuição de Chest pain type é:
# Chest pain type
# Dangerous    329179
# Hard         197278
# Common        74941
# Light         28602
# Name: count, dtype: int64
# A distribuição de FBS over 120 é:
# FBS over 120
# N    579608
# Y     50392
# Name: count, dtype: int64
# A distribuição de EKG results é:
# EKG results
# N    321438
# P    308562
# Name: count, dtype: int64
# A distribuição de Exercise angina é:
# Exercise angina
# N    457553
# Y    172447
# Name: count, dtype: int64
# A distribuição de Slope of ST é:
# Slope of ST
# Upsloping      358293
# Flat           256215
# Downsloping     15492
# Name: count, dtype: int64
# A distribuição de Heart Disease é:
# Heart Disease
# Absence     347546
# Presence    282454
# Name: count, dtype: int64

# %%
sns.histplot(data=df_att, x='Slope of ST', hue='Heart Disease', multiple='fill')
# Out:
# <Axes: xlabel='Slope of ST', ylabel='Count'>

# %%
# There, we can see the relation of Downsloping and Flat with Heart Disease is mostly the same. We may consider
# to merge them, BUT, as we are analysing any Heart Disease, the relation between it and other vars may ber
# Important to detect an specific Heart Problem, so, we shall keep it that way, but also keep in mind that may
# be a good idea to merge it later.

# %% [markdown]
# ## With that, we end or first analysis of data and features of our df, and also, from now on, we shall use df_att, and not base df to start our ML. We can, though, test it and verify if df_att have a better performance than df, or other wise, with shall be done in "first_ML.ipynb"
#
# ### It's over to the alpha version... so, finally, something has remain to the Beta...
